# %%
import pandas as pd

df = pd.read_csv("ozone-data.csv")
df.head()
# Out:
#        Date  WSR0  WSR1  WSR2  WSR3  WSR4  WSR5  WSR6  WSR7  WSR8  ...   RH50  \
# 0  1/1/1998   0.8   1.8   2.4   2.1   2.0   2.1   1.5   1.7   1.9  ...   0.15
# 1  1/2/1998   2.8   3.2   3.3   2.7   3.3   3.2   2.9   2.8   3.1  ...   0.48
# 2  1/3/1998   2.9   2.8   2.6   2.1   2.2   2.5   2.5   2.7   2.2  ...   0.60
# 3  1/4/1998   4.7   3.8   3.7   3.8   2.9   3.1   2.8   2.5   2.4  ...   0.49
# 4  1/5/1998   2.6   2.1   1.6   1.4   0.9   1.5   1.2   1.4   1.3  ...  30.00
#
#      U50    V50    HT50     KI    TT      SLP  SLP_  Precp  Class
# 0  10.67  -1.56  5795.0 -12.10  17.9  10330.0 -55.0   0.00    0.0
# 1   8.39   3.84  5805.0  14.05  29.0  10275.0 -55.0   0.00    0.0
# 2   6.94   9.80  5790.0  17.90  41.3  10235.0 -40.0   0.00    0.0
# 3   8.73  10.54  5775.0  31.15  51.7  10195.0 -40.0   2.08    0.0
# 4  30.00  30.00    30.0  30.00  30.0     30.0  30.0   0.58    0.0
#
# [5 rows x 74 columns]
